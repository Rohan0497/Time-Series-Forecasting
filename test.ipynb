# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# fix random seed for reproducibility
numpy.random.seed(7)
# Out:
# WARNING:tensorflow:From c:\Users\Rohan Thorat\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# load the dataset
dataframe = pandas.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/airline-passengers.csv', usecols=[1], engine='python')
dataset = dataframe.values
dataset = dataset.astype('float32')
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 96 48

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i + look_back, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)
# Out:
# WARNING:tensorflow:From c:\Users\Rohan Thorat\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Rohan Thorat\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Rohan Thorat\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 94/94 - 1s - loss: 0.0475 - 1s/epoch - 15ms/step
# Epoch 2/100
# 94/94 - 0s - loss: 0.0249 - 117ms/epoch - 1ms/step
# Epoch 3/100
# 94/94 - 0s - loss: 0.0180 - 147ms/epoch - 2ms/step
# Epoch 4/100
# 94/94 - 0s - loss: 0.0160 - 100ms/epoch - 1ms/step
# Epoch 5/100
# 94/94 - 0s - loss: 0.0150 - 119ms/epoch - 1ms/step
# Epoch 6/100
# 94/94 - 0s - loss: 0.0142 - 127ms/epoch - 1ms/step
# Epoch 7/100
# 94/94 - 0s - loss: 0.0133 - 122ms/epoch - 1ms/step
# Epoch 8/100
# 94/94 - 0s - loss: 0.0125 - 119ms/epoch - 1ms/step
# Epoch 9/100
# 94/94 - 0s - loss: 0.0114 - 100ms/epoch - 1ms/step
# Epoch 10/100
# 94/94 - 0s - loss: 0.0105 - 108ms/epoch - 1ms/step
# Epoch 11/100
# 94/94 - 0s - loss: 0.0096 - 119ms/epoch - 1ms/step
# Epoch 12/100
# 94/94 - 0s - loss: 0.0087 - 133ms/epoch - 1ms/step
# Epoch 13/100
# 94/94 - 0s - loss: 0.0078 - 114ms/epoch - 1ms/step
# Epoch 14/100
# 94/94 - 0s - loss: 0.0068 - 95ms/epoch - 1ms/step
# Epoch 15/100
# 94/94 - 0s - loss: 0.0060 - 105ms/epoch - 1ms/step
# Epoch 16/100
# 94/94 - 0s - loss: 0.0052 - 95ms/epoch - 1ms/step
# Epoch 17/100
# 94/94 - 0s - loss: 0.0045 - 112ms/epoch - 1ms/step
# Epoch 18/100
# 94/94 - 0s - loss: 0.0039 - 134ms/epoch - 1ms/step
# Epoch 19/100
# 94/94 - 0s - loss: 0.0034 - 107ms/epoch - 1ms/step
# Epoch 20/100
# 94/94 - 0s - loss: 0.0030 - 110ms/epoch - 1ms/step
# Epoch 21/100
# 94/94 - 0s - loss: 0.0027 - 93ms/epoch - 984us/step
# Epoch 22/100
# 94/94 - 0s - loss: 0.0024 - 94ms/epoch - 1ms/step
# Epoch 23/100
# 94/94 - 0s - loss: 0.0023 - 94ms/epoch - 1ms/step
# Epoch 24/100
# 94/94 - 0s - loss: 0.0022 - 109ms/epoch - 1ms/step
# Epoch 25/100
# 94/94 - 0s - loss: 0.0021 - 87ms/epoch - 922us/step
# Epoch 26/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 926us/step
# Epoch 27/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 28/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 1ms/step
# Epoch 29/100
# 94/94 - 0s - loss: 0.0020 - 100ms/epoch - 1ms/step
# Epoch 30/100
# 94/94 - 0s - loss: 0.0021 - 96ms/epoch - 1ms/step
# Epoch 31/100
# 94/94 - 0s - loss: 0.0020 - 79ms/epoch - 835us/step
# Epoch 32/100
# 94/94 - 0s - loss: 0.0020 - 79ms/epoch - 836us/step
# Epoch 33/100
# 94/94 - 0s - loss: 0.0020 - 83ms/epoch - 880us/step
# Epoch 34/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 1ms/step
# Epoch 35/100
# 94/94 - 0s - loss: 0.0020 - 103ms/epoch - 1ms/step
# Epoch 36/100
# 94/94 - 0s - loss: 0.0020 - 100ms/epoch - 1ms/step
# Epoch 37/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 38/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 39/100
# 94/94 - 0s - loss: 0.0020 - 90ms/epoch - 953us/step
# Epoch 40/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 922us/step
# Epoch 41/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 922us/step
# Epoch 42/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 43/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 1ms/step
# Epoch 44/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 45/100
# 94/94 - 0s - loss: 0.0020 - 101ms/epoch - 1ms/step
# Epoch 46/100
# 94/94 - 0s - loss: 0.0020 - 90ms/epoch - 960us/step
# Epoch 47/100
# 94/94 - 0s - loss: 0.0020 - 100ms/epoch - 1ms/step
# Epoch 48/100
# 94/94 - 0s - loss: 0.0020 - 84ms/epoch - 895us/step
# Epoch 49/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 50/100
# 94/94 - 0s - loss: 0.0020 - 103ms/epoch - 1ms/step
# Epoch 51/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 52/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 53/100
# 94/94 - 0s - loss: 0.0020 - 95ms/epoch - 1ms/step
# Epoch 54/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 976us/step
# Epoch 55/100
# 94/94 - 0s - loss: 0.0020 - 90ms/epoch - 962us/step
# Epoch 56/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 972us/step
# Epoch 57/100
# 94/94 - 0s - loss: 0.0020 - 103ms/epoch - 1ms/step
# Epoch 58/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 921us/step
# Epoch 59/100
# 94/94 - 0s - loss: 0.0020 - 103ms/epoch - 1ms/step
# Epoch 60/100
# 94/94 - 0s - loss: 0.0020 - 93ms/epoch - 987us/step
# Epoch 61/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 922us/step
# Epoch 62/100
# 94/94 - 0s - loss: 0.0020 - 92ms/epoch - 975us/step
# Epoch 63/100
# 94/94 - 0s - loss: 0.0020 - 91ms/epoch - 973us/step
# Epoch 64/100
# 94/94 - 0s - loss: 0.0020 - 95ms/epoch - 1ms/step
# Epoch 65/100
# 94/94 - 0s - loss: 0.0020 - 87ms/epoch - 920us/step
# Epoch 66/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 67/100
# 94/94 - 0s - loss: 0.0019 - 94ms/epoch - 1ms/step
# Epoch 68/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 69/100
# 94/94 - 0s - loss: 0.0020 - 106ms/epoch - 1ms/step
# Epoch 70/100
# 94/94 - 0s - loss: 0.0021 - 82ms/epoch - 871us/step
# Epoch 71/100
# 94/94 - 0s - loss: 0.0019 - 95ms/epoch - 1ms/step
# Epoch 72/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 73/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 74/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 75/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 76/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 77/100
# 94/94 - 0s - loss: 0.0020 - 95ms/epoch - 1ms/step
# Epoch 78/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 79/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 997us/step
# Epoch 80/100
# 94/94 - 0s - loss: 0.0020 - 100ms/epoch - 1ms/step
# Epoch 81/100
# 94/94 - 0s - loss: 0.0020 - 88ms/epoch - 932us/step
# Epoch 82/100
# 94/94 - 0s - loss: 0.0019 - 94ms/epoch - 1ms/step
# Epoch 83/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 84/100
# 94/94 - 0s - loss: 0.0021 - 94ms/epoch - 1ms/step
# Epoch 85/100
# 94/94 - 0s - loss: 0.0020 - 79ms/epoch - 836us/step
# Epoch 86/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 87/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 996us/step
# Epoch 88/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 89/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 90/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 91/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 92/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 93/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 94/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 95/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 96/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 97/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 98/100
# 94/94 - 0s - loss: 0.0020 - 94ms/epoch - 1ms/step
# Epoch 99/100
# 94/94 - 0s - loss: 0.0019 - 100ms/epoch - 1ms/step
# Epoch 100/100
# 94/94 - 0s - loss: 0.0020 - 88ms/epoch - 938us/step

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))

# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 3/3 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 8ms/step
